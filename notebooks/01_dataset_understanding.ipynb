# %% [markdown]
# # 01 Dataset Understanding
#
# ## Objective
#
# Understand the structure, features, data types, and quality of all datasets before preprocessing.
#
# ---
#
# ## Datasets Used
#
# 1. River Streamflow (CWC/India-WRIS)
# 2. Rainfall (IMD)
# 3. Temperature (IMD)
# 4. Oceanic Niño Index (NOAA)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Check total number of rows and columns
# ### There are total 9 csv's lets check total number of rows and columns in each file
# #### Files :-
# - kaveri_rainfall.csv
# - kaveri_streamflow.csv
# - kaveri_tmax_2001_2025.csv
# - kaveri_tmin_2001_2025.csv
# - krishna_rainfall.csv
# - krishna_streamflow.csv
# - krishna_tmax_2001_2025.csv
# - krishna_tmin_2001_2025.csv
# - oni.csv

# %%
kaveri_rainfall = pd.read_csv("../data/interim/kaveri_rainfall.csv")
kaveri_streamflow = pd.read_csv("../data/interim/kaveri_streamflow.csv")
kaveri_tmax = pd.read_csv("../data/interim/kaveri_tmax_2001_2025.csv")
kaveri_tmin = pd.read_csv("../data/interim/kaveri_tmin_2001_2025.csv")

print("Kaveri river basin data :- ")
print("Kaveri rainfall")
print(f"rows : {kaveri_rainfall.shape[0]}, columns : {kaveri_rainfall.shape[1]}\n")
print("Kaveri streamflow")
print(f"rows : {kaveri_streamflow.shape[0]}, columns : {kaveri_streamflow.shape[1]}\n")
print("Kaveri tmax")
print(f"rows : {kaveri_tmax.shape[0]}, columns : {kaveri_tmax.shape[1]}\n")
print("Kaveri tmin")
print(f"rows : {kaveri_tmin.shape[0]}, columns : {kaveri_tmin.shape[1]}\n")
# Out:
# Kaveri river basin data :-
# Kaveri rainfall
# rows : 9131, columns : 2
#
# Kaveri streamflow
# rows : 266597, columns : 7
#
# Kaveri tmax
# rows : 9131, columns : 2
#
# Kaveri tmin
# rows : 9131, columns : 2

# %%
krishna_rainfall = pd.read_csv("../data/interim/krishna_rainfall.csv")
krishna_streamflow = pd.read_csv("../data/interim/krishna_streamflow.csv")
krishna_tmax = pd.read_csv("../data/interim/krishna_tmax_2001_2025.csv")
krishna_tmin = pd.read_csv("../data/interim/krishna_tmin_2001_2025.csv")

print("krishna river basin data :- ")
print("krishna rainfall")
print(f"rows : {krishna_rainfall.shape[0]}, columns : {krishna_rainfall.shape[1]}\n")
print("krishna streamflow")
print(f"rows : {krishna_streamflow.shape[0]}, columns : {krishna_streamflow.shape[1]}\n")
print("krishna tmax")
print(f"rows : {krishna_tmax.shape[0]}, columns : {krishna_tmax.shape[1]}\n")
print("krishna tmin")
print(f"rows : {krishna_tmin.shape[0]}, columns : {krishna_tmin.shape[1]}\n")
# Out:
# krishna river basin data :-
# krishna rainfall
# rows : 9131, columns : 2
#
# krishna streamflow
# rows : 343261, columns : 7
#
# krishna tmax
# rows : 9131, columns : 2
#
# krishna tmin
# rows : 9131, columns : 2

# %%
oni = pd.read_csv("../data/interim/oni.csv")
print("ONI : ")
print(f"rows : {oni.shape[0]}, columns : {oni.shape[1]}\n")
# Out:
# ONI :
# rows : 919, columns : 2

# %% [markdown]
# ## For every data set we will find
# - shape
# - dtypes
# - head
# - describe
# - isnull().sum()
# - duplicated().sum()
# - columns
# - info
# - min and max date

# %%
print(f"Kaveri rainfall csv:-\n")
print(f"Shape :- \n{kaveri_rainfall.shape}\n")
print(f"Data types :- \n{kaveri_rainfall.dtypes}\n")
print(f"Top 5 rows :- \n{kaveri_rainfall.head(5)}\n")
print(f"Total nulls :- \n{kaveri_rainfall.isnull().sum()}\n")
print(f"Total duplicates :- \n{kaveri_rainfall.duplicated().sum()}\n")
print(f"Columns :- \n{kaveri_rainfall.columns}\n")
print(f"Information :- \n{kaveri_rainfall.info()}\n")
print(f"Min date :- \n{kaveri_rainfall["date"].min}\n")
print(f"Max date :- \n{kaveri_rainfall["date"].max}\n")
# Out:
# Kaveri rainfall csv:-
#
# Shape :-
# (9131, 2)
#
# Data types :-
# date            str
# rainfall    float64
# dtype: object
#
# Top 5 rows :-
#          date  rainfall
# 0  2001-01-01  4.828483
# 1  2001-01-02  5.345619
# 2  2001-01-03  1.197084
# 3  2001-01-04  0.003697
# 4  2001-01-05  0.005790
#
# Total nulls :-
# date        0
# rainfall    0
# dtype: int64
#
# Total duplicates :-
# 0
#
# Columns :-
# Index(['date', 'rainfall'], dtype='str')
#
# <class 'pandas.DataFrame'>
# RangeIndex: 9131 entries, 0 to 9130
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      9131 non-null   str
#  1   rainfall  9131 non-null   float64
# dtypes: float64(1), str(1)
# memory usage: 142.8 KB
# Information :-
# None
#
# Min date :-
# <bound method Series.min of 0       2001-01-01
# 1       2001-01-02
# 2       2001-01-03
# 3       2001-01-04
# 4       2001-01-05
#            ...
# 9126    2025-12-27
# 9127    2025-12-28
# ...

# %%
print(f"Kaveri streamflow csv:-\n")
print(f"Shape :- \n{kaveri_streamflow.shape}\n")
print(f"Data types :- \n{kaveri_streamflow.dtypes}\n")
print(f"Top 5 rows :- \n{kaveri_streamflow.head(5)}\n")
print(f"Total nulls :- \n{kaveri_streamflow.isnull().sum()}\n")
print(f"Total duplicates :- \n{kaveri_streamflow.duplicated().sum()}\n")
print(f"Columns :- \n{kaveri_streamflow.columns}\n")
print(f"Information :- \n{kaveri_streamflow.info()}\n")
print(f"Min date :- \n{kaveri_streamflow["date"].min}\n")
print(f"Max date :- \n{kaveri_streamflow["date"].max}\n")
# Out:
# Kaveri streamflow csv:-
#
# Shape :-
# (266597, 7)
#
# Data types :-
# date                str
# station_name        str
# river               str
# Basin               str
# Latitude        float64
# Longitude       float64
# streamflow      float64
# dtype: object
#
# Top 5 rows :-
#          date     station_name    river    Basin   Latitude  Longitude  \
# 0  2001-01-01         KOLLEGAL  Cauvery  Cauvery  12.189444  77.101944
# 1  2001-01-01           KUDIGE  Cauvery  Cauvery  12.502500  75.960833
# 2  2001-01-01  NALLAMARANPATTY  Cauvery  Cauvery  10.880833  77.984722
# 3  2001-01-01          THOPPUR  Cauvery  Cauvery  11.938333  78.057222
# 4  2001-01-01         KODUMUDI  Cauvery  Cauvery  11.080000  77.890000
#
#    streamflow
# 0  119.927270
# 1   15.905964
# 2   16.581580
# 3    0.308000
# 4  319.175900
#
# Total nulls :-
# date            0
# station_name    0
# river           0
# Basin           0
# Latitude        0
# Longitude       0
# streamflow      0
# dtype: int64
# ...

# %%
print(f"Kaveri tmax 2001-2025 csv:-\n")
print(f"Shape :- \n{kaveri_tmax.shape}\n")
print(f"Data types :- \n{kaveri_tmax.dtypes}\n")
print(f"Top 5 rows :- \n{kaveri_tmax.head(5)}\n")
print(f"Total nulls :- \n{kaveri_tmax.isnull().sum()}\n")
print(f"Total duplicates :- \n{kaveri_tmax.duplicated().sum()}\n")
print(f"Columns :- \n{kaveri_tmax.columns}\n")
print(f"Information :- \n{kaveri_tmax.info()}\n")
print(f"Min date :- \n{kaveri_tmax["date"].min}\n")
print(f"Max date :- \n{kaveri_tmax["date"].max}\n")
# Out:
# Kaveri tmax 2001-2025 csv:-
#
# Shape :-
# (9131, 2)
#
# Data types :-
# time        str
# tmax    float64
# dtype: object
#
# Top 5 rows :-
#          time       tmax
# 0  2001-01-01  28.537500
# 1  2001-01-02  28.472502
# 2  2001-01-03  28.538750
# 3  2001-01-04  28.698122
# 4  2001-01-05  29.090000
#
# Total nulls :-
# time    0
# tmax    0
# dtype: int64
#
# Total duplicates :-
# 0
#
# Columns :-
# Index(['time', 'tmax'], dtype='str')
#
# <class 'pandas.DataFrame'>
# RangeIndex: 9131 entries, 0 to 9130
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    9131 non-null   str
#  1   tmax    9131 non-null   float64
# dtypes: float64(1), str(1)
# memory usage: 142.8 KB
# Information :-
# None
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...

# %%
print(f"Kaveri tmin 2001-2025 csv:-\n")
print(f"Shape :- \n{kaveri_tmin.shape}\n")
print(f"Data types :- \n{kaveri_tmin.dtypes}\n")
print(f"Top 5 rows :- \n{kaveri_tmin.head(5)}\n")
print(f"Total nulls :- \n{kaveri_tmin.isnull().sum()}\n")
print(f"Total duplicates :- \n{kaveri_tmin.duplicated().sum()}\n")
print(f"Columns :- \n{kaveri_tmin.columns}\n")
print(f"Information :- \n{kaveri_tmin.info()}\n")
print(f"Min date :- \n{kaveri_tmin["date"].min}\n")
print(f"Max date :- \n{kaveri_tmin["date"].max}\n")
# Out:
# Kaveri tmin 2001-2025 csv:-
#
# Shape :-
# (9131, 2)
#
# Data types :-
# date        str
# tmin    float64
# dtype: object
#
# Top 5 rows :-
#          date       tmin
# 0  2001-01-01  18.696250
# 1  2001-01-02  16.838501
# 2  2001-01-03  17.249002
# 3  2001-01-04  17.257750
# 4  2001-01-05  17.110000
#
# Total nulls :-
# date    0
# tmin    0
# dtype: int64
#
# Total duplicates :-
# 0
#
# Columns :-
# Index(['date', 'tmin'], dtype='str')
#
# <class 'pandas.DataFrame'>
# RangeIndex: 9131 entries, 0 to 9130
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    9131 non-null   str
#  1   tmin    9131 non-null   float64
# dtypes: float64(1), str(1)
# memory usage: 142.8 KB
# Information :-
# None
#
# Min date :-
# <bound method Series.min of 0       2001-01-01
# 1       2001-01-02
# 2       2001-01-03
# 3       2001-01-04
# 4       2001-01-05
#            ...
# 9126    2025-12-27
# 9127    2025-12-28
# ...

# %%
print(f"Krishna rainfall csv:-\n")
print(f"Shape :- \n{krishna_rainfall.shape}\n")
print(f"Data types :- \n{krishna_rainfall.dtypes}\n")
print(f"Top 5 rows :- \n{krishna_rainfall.head(5)}\n")
print(f"Total nulls :- \n{krishna_rainfall.isnull().sum()}\n")
print(f"Total duplicates :- \n{krishna_rainfall.duplicated().sum()}\n")
print(f"Columns :- \n{krishna_rainfall.columns}\n")
print(f"Information :- \n{krishna_rainfall.info()}\n")
print(f"Min date :- \n{krishna_rainfall["date"].min}\n")
print(f"Max date :- \n{krishna_rainfall["date"].max}\n")
# Out:
# Krishna rainfall csv:-
#
# Shape :-
# (9131, 2)
#
# Data types :-
# date            str
# rainfall    float64
# dtype: object
#
# Top 5 rows :-
#          date  rainfall
# 0  2001-01-01  1.237529
# 1  2001-01-02  0.387293
# 2  2001-01-03  0.170663
# 3  2001-01-04  0.000000
# 4  2001-01-05  0.361901
#
# Total nulls :-
# date        0
# rainfall    0
# dtype: int64
#
# Total duplicates :-
# 0
#
# Columns :-
# Index(['date', 'rainfall'], dtype='str')
#
# <class 'pandas.DataFrame'>
# RangeIndex: 9131 entries, 0 to 9130
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      9131 non-null   str
#  1   rainfall  9131 non-null   float64
# dtypes: float64(1), str(1)
# memory usage: 142.8 KB
# Information :-
# None
#
# Min date :-
# <bound method Series.min of 0       2001-01-01
# 1       2001-01-02
# 2       2001-01-03
# 3       2001-01-04
# 4       2001-01-05
#            ...
# 9126    2025-12-27
# 9127    2025-12-28
# ...

# %%
print(f"Krishna streamflow csv:-\n")
print(f"Shape :- \n{krishna_streamflow.shape}\n")
print(f"Data types :- \n{krishna_streamflow.dtypes}\n")
print(f"Top 5 rows :- \n{krishna_streamflow.head(5)}\n")
print(f"Total nulls :- \n{krishna_streamflow.isnull().sum()}\n")
print(f"Total duplicates :- \n{krishna_streamflow.duplicated().sum()}\n")
print(f"Columns :- \n{krishna_streamflow.columns}\n")
print(f"Information :- \n{krishna_streamflow.info()}\n")
print(f"Min date :- \n{krishna_streamflow["date"].min}\n")
print(f"Max date :- \n{krishna_streamflow["date"].max}\n")
# Out:
# Krishna streamflow csv:-
#
# Shape :-
# (343261, 7)
#
# Data types :-
# date                str
# station_name        str
# river               str
# Basin               str
# Latitude        float64
# Longitude       float64
# streamflow      float64
# dtype: object
#
# Top 5 rows :-
#          date   station_name    river    Basin   Latitude  Longitude  \
# 0  2001-01-01      Bawapuram  Krishna  Krishna  15.882500  77.957222
# 1  2001-01-01        Malkhed  Krishna  Krishna  17.203333  77.156389
# 2  2001-01-01  Cholachagudda  Krishna  Krishna  15.872222  75.723333
# 3  2001-01-01    Mantralayam  Krishna  Krishna  15.940000  77.420000
# 4  2001-01-01          Takli  Krishna  Krishna  17.414167  75.847778
#
#    streamflow
# 0    2.664215
# 1    3.298000
# 2   30.840000
# 3   11.210050
# 4    0.000000
#
# Total nulls :-
# date            0
# station_name    0
# river           0
# Basin           0
# Latitude        0
# Longitude       0
# streamflow      0
# dtype: int64
#
# ...

# %%
print(f"Krishna tmax csv:-\n")
print(f"Shape :- \n{krishna_tmax.shape}\n")
print(f"Data types :- \n{krishna_tmax.dtypes}\n")
print(f"Top 5 rows :- \n{krishna_tmax.head(5)}\n")
print(f"Total nulls :- \n{krishna_tmax.isnull().sum()}\n")
print(f"Total duplicates :- \n{krishna_tmax.duplicated().sum()}\n")
print(f"Columns :- \n{krishna_tmax.columns}\n")
print(f"Information :- \n{krishna_tmax.info()}\n")
print(f"Min date :- \n{krishna_tmax["date"].min}\n")
print(f"Max date :- \n{krishna_tmax["date"].max}\n")
# Out:
# Krishna tmax csv:-
#
# Shape :-
# (9131, 2)
#
# Data types :-
# date        str
# tmax    float64
# dtype: object
#
# Top 5 rows :-
#          date       tmax
# 0  2001-01-01  28.144247
# 1  2001-01-02  28.029003
# 2  2001-01-03  27.923252
# 3  2001-01-04  28.633503
# 4  2001-01-05  29.784500
#
# Total nulls :-
# date    0
# tmax    0
# dtype: int64
#
# Total duplicates :-
# 0
#
# Columns :-
# Index(['date', 'tmax'], dtype='str')
#
# <class 'pandas.DataFrame'>
# RangeIndex: 9131 entries, 0 to 9130
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    9131 non-null   str
#  1   tmax    9131 non-null   float64
# dtypes: float64(1), str(1)
# memory usage: 142.8 KB
# Information :-
# None
#
# Min date :-
# <bound method Series.min of 0       2001-01-01
# 1       2001-01-02
# 2       2001-01-03
# 3       2001-01-04
# 4       2001-01-05
#            ...
# 9126    2025-12-27
# 9127    2025-12-28
# 9128    2025-12-29
# ...

# %%
print(f"Krishna tmin csv:-\n")
print(f"Shape :- \n{krishna_tmin.shape}\n")
print(f"Data types :- \n{krishna_tmin.dtypes}\n")
print(f"Top 5 rows :- \n{krishna_tmin.head(5)}\n")
print(f"Total nulls :- \n{krishna_tmin.isnull().sum()}\n")
print(f"Total duplicates :- \n{krishna_tmin.duplicated().sum()}\n")
print(f"Columns :- \n{krishna_tmin.columns}\n")
print(f"Information :- \n{krishna_tmin.info()}\n")
print(f"Min date :- \n{krishna_tmin["date"].min}\n")
print(f"Max date :- \n{krishna_tmin["date"].max}\n")
# Out:
# Krishna tmin csv:-
#
# Shape :-
# (9131, 2)
#
# Data types :-
# date        str
# tmin    float64
# dtype: object
#
# Top 5 rows :-
#          date       tmin
# 0  2001-01-01  18.696250
# 1  2001-01-02  16.838501
# 2  2001-01-03  17.249002
# 3  2001-01-04  17.257750
# 4  2001-01-05  17.110000
#
# Total nulls :-
# date    0
# tmin    0
# dtype: int64
#
# Total duplicates :-
# 0
#
# Columns :-
# Index(['date', 'tmin'], dtype='str')
#
# <class 'pandas.DataFrame'>
# RangeIndex: 9131 entries, 0 to 9130
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    9131 non-null   str
#  1   tmin    9131 non-null   float64
# dtypes: float64(1), str(1)
# memory usage: 142.8 KB
# Information :-
# None
#
# Min date :-
# <bound method Series.min of 0       2001-01-01
# 1       2001-01-02
# 2       2001-01-03
# 3       2001-01-04
# 4       2001-01-05
#            ...
# 9126    2025-12-27
# 9127    2025-12-28
# 9128    2025-12-29
# ...
